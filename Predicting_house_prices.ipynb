# %%
#Implementation of house price prediction model(Coursera ML:Week2)

# %%
import pandas as pd

# %%
sales =pd.read_csv('data/home_data.csv')

# %%
sales
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000   221900         3       1.00         1180
# 1      6414100192  20141209T000000   538000         3       2.25         2570
# 2      5631500400  20150225T000000   180000         2       1.00          770
# 3      2487200875  20141209T000000   604000         4       3.00         1960
# 4      1954400510  20150218T000000   510000         3       2.00         1680
# 5      7237550310  20140512T000000  1225000         4       4.50         5420
# 6      1321400060  20140627T000000   257500         3       2.25         1715
# 7      2008000270  20150115T000000   291850         3       1.50         1060
# 8      2414600126  20150415T000000   229500         3       1.00         1780
# 9      3793500160  20150312T000000   323000         3       2.50         1890
# 10     1736800520  20150403T000000   662500         3       2.50         3560
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(sales.sqft_living,sales.price)

# %%
plt.xlabel('square foot')
plt.ylabel('price')

# %%
plt.show()

# %%
#Building regression model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import numpy as np
#root mean sqaure value
def rmse(clf, data):
    "Calculates RSS on classifier and data"
    return np.sqrt(np.mean((data.price - clf.predict(data.drop("price", axis=1)))**2))
#building function
def build_model(df):
    
    #Split on train/test data
    train_data, test_data = train_test_split(df, train_size=.8, random_state=0)
    
    clf = LinearRegression()
    clf.fit(train_data.drop("price", axis=1), train_data.price)
    
    print ("Accuracy=%f"%clf.score(test_data.drop("price", axis=1), test_data.price))
    print ("Rmse=%f"%rmse(clf,df))
    return clf, train_data, test_data

clf, train_data, test_data = build_model(sales[["sqft_living", "price"]])
# Out:
# Accuracy=0.479158
# Rmse=261468.788750

# %%
#ans1_average price zipcode=98039

# %%
sales['price'][sales['zipcode'] == 98039].mean()
# Out:
# 2160606.6

# %%
#ans2_fraction of house b/w 2k and 4k sqft

# %%
sqft_2k=sales['sqft_living'][sales['sqft_living']>2000]
sqft_4k=sales['sqft_living'][sales['sqft_living']>4000]
ans2=(len(sqft_2k)-len(sqft_4k))/len(sales)
ans2
# Out:
# 0.42187572294452413

# %%
#creating model using my_features

# %%
my_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode','price']
sales_mdata = sales[my_features]

# %%
clf1 ,train_data,test_data =build_model(sales_mdata)
# Out:
# Accuracy=0.499359
# Rmse=255686.411620

# %%
#creating model using advanced features

# %%
advanced_features=[
'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode',
'condition', # condition of house				
'grade', # measure of quality of construction				
'waterfront', # waterfront property				
'view', # type of view				
'sqft_above', # square feet above ground				
'sqft_basement', # square feet in basement				
'yr_built', # the year built				
'yr_renovated', # the year renovated				
'lat', 'long', # the lat-long of the parcel				
'sqft_living15', # average sq.ft. of 15 nearest neighbors 				
'sqft_lot15',# average lot size of 15 nearest neighbors 
'price'#price
]
sales_advdata=sales[advanced_features]

# %%
clf2 ,train_data,test_data =build_model(sales_advdata)
# Out:
# Accuracy=0.694931
# Rmse=201209.444071

# %%
#Rmse difference b/w two models(Myfeatures/Advancedfeatures)

# %%
ans3=255686.41162-201209.444071
ans3
# Out:
# 54476.96754899999
